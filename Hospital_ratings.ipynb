# %%
#import dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# get the csv file location and read the Hospital_patient_satisfaction csv file
csv_file = "../cms_hospital_patient_satisfaction_2020.csv"

# %%
#store the csv file into a dataframe
ratings_df = pd.read_csv(csv_file)
ratings_df.head()
# Out:
# /Users/olu/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (0,14,17,19,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   Facility ID                     Facility Name                 Address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name    Phone Number      HCAHPS Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON  (334) 793-8701           H_COMP_1_A_P
# 1  DOTHAN    AL     36301     HOUSTON  (334) 793-8701          H_COMP_1_SN_P
# 2  DOTHAN    AL     36301     HOUSTON  (334) 793-8701           H_COMP_1_U_P
# 3  DOTHAN    AL     36301     HOUSTON  (334) 793-8701  H_COMP_1_LINEAR_SCORE
# 4  DOTHAN    AL     36301     HOUSTON  (334) 793-8701   H_COMP_1_STAR_RATING
#
#                                      HCAHPS Question  ...  \
# 0  Patients who reported that their nurses "Alway...  ...
# 1  Patients who reported that their nurses "Somet...  ...
# 2  Patients who reported that their nurses "Usual...  ...
# 3            Nurse communication - linear mean score  ...
# 4                  Nurse communication - star rating  ...
#
#   Readmission national comparison Readmission national comparison footnote  \
# 0      Below the national average                                      NaN
# 1      Below the national average                                      NaN
# 2      Below the national average                                      NaN
# 3      Below the national average                                      NaN
# 4      Below the national average                                      NaN
#
#    Patient experience national comparison  \
# 0              Below the national average
# 1              Below the national average
# 2              Below the national average
# 3              Below the national average
# 4              Below the national average
#
#   Patient experience national comparison footnote  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Effectiveness of care national comparison  \
# 0              Same as the national average
# 1              Same as the national average
# 2              Same as the national average
# 3              Same as the national average
# 4              Same as the national average
#
#   Effectiveness of care national comparison footnote  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Timeliness of care national comparison  \
# 0           Same as the national average
# 1           Same as the national average
# 2           Same as the national average
# 3           Same as the national average
# 4           Same as the national average
#
#   Timeliness of care national comparison footnote  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Efficient use of medical imaging national comparison  \
# 0                       Same as the national average
# 1                       Same as the national average
# 2                       Same as the national average
# 3                       Same as the national average
# 4                       Same as the national average
#
#   Efficient use of medical imaging national comparison footnote
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 43 columns]

# %%
#Selecting just the columns with applicable information and reduce clutter
new_ratings_df = ratings_df[['Facility ID', 'Facility Name', 'Address', 'City', 'State', 'County Name',
                             'Number of Completed Surveys', 'Survey Response Rate Percent', 'Start Date',
                             'End Date', 'Year', 'Hospital Type', 'Hospital overall rating',
                             'Mortality national comparison', 'Safety of care national comparison',
                             'Readmission national comparison', 'Patient experience national comparison',
                             'Effectiveness of care national comparison', 'Timeliness of care national comparison']].copy()
new_ratings_df.head()
# Out:
#   Facility ID                     Facility Name                 Address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State County Name Number of Completed Surveys  \
# 0  DOTHAN    AL     HOUSTON                         535
# 1  DOTHAN    AL     HOUSTON                         535
# 2  DOTHAN    AL     HOUSTON                         535
# 3  DOTHAN    AL     HOUSTON                         535
# 4  DOTHAN    AL     HOUSTON                         535
#
#   Survey Response Rate Percent  Start Date    End Date  Year  \
# 0                           22  07/01/2018  06/30/2019  2020
# 1                           22  07/01/2018  06/30/2019  2020
# 2                           22  07/01/2018  06/30/2019  2020
# 3                           22  07/01/2018  06/30/2019  2020
# 4                           22  07/01/2018  06/30/2019  2020
#
#           Hospital Type Hospital overall rating Mortality national comparison  \
# 0  Acute Care Hospitals                       2    Below the national average
# 1  Acute Care Hospitals                       2    Below the national average
# 2  Acute Care Hospitals                       2    Below the national average
# 3  Acute Care Hospitals                       2    Below the national average
# 4  Acute Care Hospitals                       2    Below the national average
#
#   Safety of care national comparison Readmission national comparison  \
# 0       Same as the national average      Below the national average
# 1       Same as the national average      Below the national average
# 2       Same as the national average      Below the national average
# 3       Same as the national average      Below the national average
# 4       Same as the national average      Below the national average
#
#   Patient experience national comparison  \
# 0             Below the national average
# 1             Below the national average
# 2             Below the national average
# 3             Below the national average
# 4             Below the national average
#
#   Effectiveness of care national comparison  \
# 0              Same as the national average
# 1              Same as the national average
# 2              Same as the national average
# 3              Same as the national average
# 4              Same as the national average
#
#   Timeliness of care national comparison
# 0           Same as the national average
# 1           Same as the national average
# 2           Same as the national average
# 3           Same as the national average
# 4           Same as the national average

# %%
#rename the columns of the dataframe to match the columns of the table in pgadmin database
renew_ratings_df = new_ratings_df.rename(columns={"Facility ID": "facility_id", "Facility Name": "facility_name", "Address": "address",
                               "City": "city", "State": "state_", "County Name": "county_name",
                               "Number of Completed Surveys": "num_of_surveys",
                               "Survey Response Rate Percent": "survey_response_rate", "Start Date": "start_date",
                               "End Date": "end_date", "Year": "year_", "Hospital Type": "hospital_type",
                               "Hospital overall rating": "hospital_rating",
                               "Mortality national comparison": "mortality_national_comparison",
                               "Safety of care national comparison": "safety_of_care_national_comparison",
                               "Readmission national comparison": "readmission_national_comparison",
                               "Patient experience national comparison": "patient_experience_national_comparison",
                               "Effectiveness of care national comparison": "effectiveness_of_care_national_comparison",
                               "Timeliness of care national comparison": "timeliness_of_care_national_comparison"})
renew_ratings_df
# Out:
#        facility_id                     facility_name  \
# 0           010001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1           010001  SOUTHEAST ALABAMA MEDICAL CENTER
# 2           010001  SOUTHEAST ALABAMA MEDICAL CENTER
# 3           010001  SOUTHEAST ALABAMA MEDICAL CENTER
# 4           010001  SOUTHEAST ALABAMA MEDICAL CENTER
# ...            ...                               ...
# 442582      670130               SOUTHCROSS HOSPITAL
# 442583      670130               SOUTHCROSS HOSPITAL
# 442584      670130               SOUTHCROSS HOSPITAL
# 442585      670130               SOUTHCROSS HOSPITAL
# 442586      670130               SOUTHCROSS HOSPITAL
#
#                                     address         city state_ county_name  \
# 0                    1108 ROSS CLARK CIRCLE       DOTHAN     AL     HOUSTON
# 1                    1108 ROSS CLARK CIRCLE       DOTHAN     AL     HOUSTON
# 2                    1108 ROSS CLARK CIRCLE       DOTHAN     AL     HOUSTON
# 3                    1108 ROSS CLARK CIRCLE       DOTHAN     AL     HOUSTON
# 4                    1108 ROSS CLARK CIRCLE       DOTHAN     AL     HOUSTON
# ...                                     ...          ...    ...         ...
# 442582  4243 EAST SOUTHCROSS BLVD SUITE 100  SAN ANTONIO     TX       BEXAR
# 442583  4243 EAST SOUTHCROSS BLVD SUITE 100  SAN ANTONIO     TX       BEXAR
# 442584  4243 EAST SOUTHCROSS BLVD SUITE 100  SAN ANTONIO     TX       BEXAR
# 442585  4243 EAST SOUTHCROSS BLVD SUITE 100  SAN ANTONIO     TX       BEXAR
# 442586  4243 EAST SOUTHCROSS BLVD SUITE 100  SAN ANTONIO     TX       BEXAR
#
#        num_of_surveys survey_response_rate  start_date    end_date  year_  \
# 0                 535                   22  07/01/2018  06/30/2019   2020
# 1                 535                   22  07/01/2018  06/30/2019   2020
# 2                 535                   22  07/01/2018  06/30/2019   2020
# 3                 535                   22  07/01/2018  06/30/2019   2020
# 4                 535                   22  07/01/2018  06/30/2019   2020
# ...               ...                  ...         ...         ...    ...
# 442582  Not Available        Not Available  07/01/2018  06/30/2019   2020
# 442583  Not Available        Not Available  07/01/2018  06/30/2019   2020
# 442584  Not Available        Not Available  07/01/2018  06/30/2019   2020
# 442585  Not Available        Not Available  07/01/2018  06/30/2019   2020
# 442586  Not Available        Not Available  07/01/2018  06/30/2019   2020
#
#                hospital_type hospital_rating mortality_national_comparison  \
# 0       Acute Care Hospitals               2    Below the national average
# 1       Acute Care Hospitals               2    Below the national average
# 2       Acute Care Hospitals               2    Below the national average
# 3       Acute Care Hospitals               2    Below the national average
# 4       Acute Care Hospitals               2    Below the national average
# ...                      ...             ...                           ...
# 442582  Acute Care Hospitals   Not Available                 Not Available
# 442583  Acute Care Hospitals   Not Available                 Not Available
# 442584  Acute Care Hospitals   Not Available                 Not Available
# 442585  Acute Care Hospitals   Not Available                 Not Available
# 442586  Acute Care Hospitals   Not Available                 Not Available
#
#        safety_of_care_national_comparison readmission_national_comparison  \
# 0            Same as the national average      Below the national average
# 1            Same as the national average      Below the national average
# 2            Same as the national average      Below the national average
# 3            Same as the national average      Below the national average
# 4            Same as the national average      Below the national average
# ...                                   ...                             ...
# 442582                      Not Available                   Not Available
# 442583                      Not Available                   Not Available
# 442584                      Not Available                   Not Available
# 442585                      Not Available                   Not Available
# 442586                      Not Available                   Not Available
#
#        patient_experience_national_comparison  \
# 0                  Below the national average
# 1                  Below the national average
# 2                  Below the national average
# 3                  Below the national average
# 4                  Below the national average
# ...                                       ...
# 442582                          Not Available
# 442583                          Not Available
# 442584                          Not Available
# 442585                          Not Available
# 442586                          Not Available
#
#        effectiveness_of_care_national_comparison  \
# 0                   Same as the national average
# 1                   Same as the national average
# 2                   Same as the national average
# 3                   Same as the national average
# 4                   Same as the national average
# ...                                          ...
# 442582                             Not Available
# 442583                             Not Available
# 442584                             Not Available
# 442585                             Not Available
# 442586                             Not Available
#
#        timeliness_of_care_national_comparison
# 0                Same as the national average
# 1                Same as the national average
# 2                Same as the national average
# 3                Same as the national average
# 4                Same as the national average
# ...                                       ...
# 442582                          Not Available
# 442583                          Not Available
# 442584                          Not Available
# 442585                          Not Available
# 442586                          Not Available
#
# [442587 rows x 19 columns]

# %%
#making connection to pgAdmin
protocol = 'postgresql'
username = 'mypostgres'
password = 'Wilson14'
host = 'localhost'
port = 5432
database_name = 'customer_ratings_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %%
#looking up the tables in the database
engine.table_names()
# Out:
# /Users/olu/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
# ['ratings']

# %%
#load the ratings DataFrame into the customer_ratings_db database
renew_ratings_df.to_sql(name='ratings', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# StringDataRightTruncation                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1788                     self.dialect.do_executemany(
# -> 1789                         cursor, statement, parameters, context
#    1790                     )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     956                 fetch=bool(context.compiled.returning),
# --> 957                 **kwargs
#     958             )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/psycopg2/extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1298         parts[-1:] = post
# -> 1299         cur.execute(b''.join(parts))
#    1300         if fetch:
#
# StringDataRightTruncation: value too long for type character varying(30)
#
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# /var/folders/js/5cgn5z557kj6t6y5rzkjs4t00000gn/T/ipykernel_17237/11700085.py in <module>
#       1 #load the ratings DataFrame into the customer_ratings_db database
# ----> 2 renew_ratings_df.to_sql(name='ratings', con=engine, if_exists='append', index=False)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1768             chunksize=chunksize,
#    1769             method=method,
# -> 1770             **engine_kwargs,
#    1771         )
#    1772
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1293             )
#    1294         else:
# -> 1295             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1296
#    1297     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     324         if _force or self.supports_execution:
#     325             return connection._execute_clauseelement(
# --> 326                 self, multiparams, params, execution_options
#     327             )
#     328         else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1495             elem,
#    1496             extracted_params,
# -> 1497             cache_hit=cache_hit,
#    1498         )
#    1499         if has_events:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1850         except BaseException as e:
#    1851             self._handle_dbapi_exception(
# -> 1852                 e, statement, parameters, cursor, context
#    1853             )
#    1854
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2031             elif should_wrap:
#    2032                 util.raise_(
# -> 2033                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2034                 )
#    2035             else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1787                 if not evt_handled:
#    1788                     self.dialect.do_executemany(
# -> 1789                         cursor, statement, parameters, context
#    1790                     )
#    1791             elif not parameters and context.no_parameters:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     955                 template=executemany_values,
#     956                 fetch=bool(context.compiled.returning),
# --> 957                 **kwargs
#     958             )
#     959
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/psycopg2/extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1297             parts.append(b',')
#    1298         parts[-1:] = post
# -> 1299         cur.execute(b''.join(parts))
#    1300         if fetch:
#    1301             result.extend(cur.fetchall())
#
# DataError: (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(30)
#
# [SQL: INSERT INTO ratings (facility_id, facility_name, address, city, state_, county_name, num_of_surveys, survey_response_rate, start_date, end_date, year_, hospital_type, hospital_rating, mortality_national_comparison, safety_of_care_national_comparison, readmission_national_comparison, patient_experience_national_comparison, effectiveness_of_care_national_comparison, timeliness_of_care_national_comparison) VALUES (%(facility_id)s, %(facility_name)s, %(address)s, %(city)s, %(state_)s, %(county_name)s, %(num_of_surveys)s, %(survey_response_rate)s, %(start_date)s, %(end_date)s, %(year_)s, %(hospital_type)s, %(hospital_rating)s, %(mortality_national_comparison)s, %(safety_of_care_national_comparison)s, %(readmission_national_comparison)s, %(patient_experience_national_comparison)s, %(effectiveness_of_care_national_comparison)s, %(timeliness_of_care_national_comparison)s)]
# [parameters: ({'facility_id': '010001', 'facility_name': 'SOUTHEAST ALABAMA MEDICAL CENTER', 'address': '1108 ROSS CLARK CIRCLE', 'city': 'DOTHAN', 'state_': 'AL', 'county_name': 'HOUSTON', 'num_of_surveys': '535', 'survey_response_rate': '22', 'start_date': '07/01/2018', 'end_date': '06/30/2019', 'year_': 2020, 'hospital_type': 'Acute Care Hospitals', 'hospital_rating': '2', 'mortality_national_comparison': 'Below the national average', 'safety_of_care_national_comparison': 'Same as the national average', 'readmission_national_comparison': 'Below the national average', 'patient_experience_national_comparison': 'Below the national average', 'effectiveness_of_care_national_comparison': 'Same as the national average', 'timeliness_of_care_national_comparison': 'Same as the national average'}, {'facility_id': '010001', 'facility_name': 'SOUTHEAST ALABAMA MEDICAL CENTER', 'address': '1108 ROSS CLARK CIRCLE', 'city': 'DOTHAN', 'state_': 'AL', 'county_name': 'HOUSTON', 'num_of_surveys': '535', 'survey_response_rate': '22', 'start_date': '07/01/2018', 'end_date': '06/30/2019', 'year_': 2020, 'hospital_type': 'Acute Care Hospitals', 'hospital_rating': '2', 'mortality_national_comparison': 'Below the national average', 'safety_of_care_national_comparison': 'Same as the national average', 'readmission_national_comparison': 'Below the national average', 'patient_experience_national_comparison': 'Below the national average', 'effectiveness_of_care_national_comparison': 'Same as the national average', 'timeliness_of_care_national_comparison': 'Same as the national average'}, {'facility_id': '010001', 'facility_name': 'SOUTHEAST ALABAMA MEDICAL CENTER', 'address': '1108 ROSS CLARK CIRCLE', 'city': 'DOTHAN', 'state_': 'AL', 'county_name': 'HOUSTON', 'num_of_surveys': '535', 'survey_response_rate': '22', 'start_date': '07/01/2018', 'end_date': '06/30/2019', 'year_': 2020, 'hospital_type': 'Acute Care Hospitals', 'hospital_rating': '2', 'mortality_national_comparison': 'Below the national average', 'safety_of_care_national_comparison': 'Same as the national average', 'readmission_national_comparison': 'Below the national average', 'patient_experience_national_comparison': 'Below the national average', 'effectiveness_of_care_national_comparison': 'Same as the national average', 'timeliness_of_care_national_comparison': 'Same as the national average'}, {'facility_id': '010001', 'facility_name': 'SOUTHEAST ALABAMA MEDICAL CENTER', 'address': '1108 ROSS CLARK CIRCLE', 'city': 'DOTHAN', 'state_': 'AL', 'county_name': 'HOUSTON', 'num_of_surveys': '535', 'survey_response_rate': '22', 'start_date': '07/01/2018', 'end_date': '06/30/2019', 'year_': 2020, 'hospital_type': 'Acute Care Hospitals', 'hospital_rating': '2', 'mortality_national_comparison': 'Below the national average', 'safety_of_care_national_comparison': 'Same as the national average', 'readmission_national_comparison': 'Below the national average', 'patient_experience_national_comparison': 'Below the national average', 'effectiveness_of_care_national_comparison': 'Same as the national average', 'timeliness_of_care_national_comparison': 'Same as the national average'}, {'facility_id': '010001', 'facility_name': 'SOUTHEAST ALABAMA MEDICAL CENTER', 'address': '1108 ROSS CLARK CIRCLE', 'city': 'DOTHAN', 'state_': 'AL', 'county_name': 'HOUSTON', 'num_of_surveys': '535', 'survey_response_rate': '22', 'start_date': '07/01/2018', 'end_date': '06/30/2019', 'year_': 2020, 'hospital_type': 'Acute Care Hospitals', 'hospital_rating': '2', 'mortality_national_comparison': 'Below the national average', 'safety_of_care_national_comparison': 'Same as the national average', 'readmission_national_comparison': 'Below the national average', 'patient_experience_national_comparison': 'Below the national average', 'effectiveness_of_care_national_comparison': 'Same as the national average', 'timeliness_of_care_national_comparison': 'Same as the national average'}, {'facility_id': '010001', 'facility_name': 'SOUTHEA ...
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
